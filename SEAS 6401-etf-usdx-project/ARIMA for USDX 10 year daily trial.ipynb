# <bound method DataFrame.info of             Date        Open        High  ...       Close   Adj Close    Volume
# 0     2010-01-04   46.330002   46.490002  ...   46.419998   41.424458  62822800
# 1     2010-01-05   46.389999   46.500000  ...   46.419998   41.424458  62935600
# 2     2010-01-06   46.400002   46.549999  ...   46.139999   41.174580  96033000
# 3     2010-01-07   46.209999   46.270000  ...   46.169998   41.201344  77094100
# 4     2010-01-08   46.070000   46.549999  ...   46.549999   41.540462  88886600
# ...          ...         ...         ...  ...         ...         ...       ...
# 2991  2021-11-18  399.730011  402.269989  ...  401.750000  401.750000  45721500
# 2992  2021-11-19  403.429993  405.299988  ...  403.989990  403.989990  45138700
# 2993  2021-11-22  405.570007  408.709991  ...  399.299988  399.299988  61715400
# 2994  2021-11-23  398.109985  400.230011  ...  397.480011  397.480011  70098700
# ...

# %%
XLE.info
# Out:
# <bound method DataFrame.info of             Date       Open       High  ...      Close  Adj Close    Volume
# 0     2010-01-04  57.919998  58.810001  ...  58.810001  40.638012  16928400
# 1     2010-01-05  58.889999  59.410000  ...  59.290001  40.969688  17368100
# 2     2010-01-06  59.320000  60.180000  ...  60.000000  41.460300  24351900
# 3     2010-01-07  59.740002  60.009998  ...  59.910000  41.398117  17449500
# 4     2010-01-08  59.700001  60.349998  ...  60.299999  41.667599  13344300
# ...          ...        ...        ...  ...        ...        ...       ...
# 2991  2021-11-18  57.099998  57.549999  ...  56.889999  56.889999  28955500
# 2992  2021-11-19  55.660000  55.810001  ...  54.669998  54.669998  45673300
# 2993  2021-11-22  54.590000  56.480000  ...  55.639999  55.639999  33892900
# 2994  2021-11-23  56.369999  57.540001  ...  57.349998  57.349998  33862300
# 2995  2021-11-24  57.049999  58.240002  ...  57.910000  57.910000  21434300
#
# [2996 rows x 7 columns]>

# %%
XLV.info
# Out:
# <bound method DataFrame.info of             Date        Open        High  ...       Close   Adj Close    Volume
# 0     2010-01-04   31.469999   31.620001  ...   31.610001   25.804001   5580900
# 1     2010-01-05   31.559999   31.670000  ...   31.299999   25.550949   5428600
# 2     2010-01-06   31.299999   31.620001  ...   31.620001   25.812166   4883600
# 3     2010-01-07   31.500000   31.730000  ...   31.730000   25.901960   6114600
# 4     2010-01-08   31.790001   31.809999  ...   31.780001   25.942774   4284800
# ...          ...         ...         ...  ...         ...         ...       ...
# 2991  2021-11-18  133.869995  134.119995  ...  133.779999  133.779999   9029300
# 2992  2021-11-19  134.179993  134.630005  ...  132.970001  132.970001  10166100
# 2993  2021-11-22  133.160004  133.619995  ...  132.369995  132.369995  11146200
# 2994  2021-11-23  131.750000  132.649994  ...  132.509995  132.509995  12075200
# ...

# %%
#USDX dataframe has 2973 rows and other 3 ETF has 2996 rows, we drop the rows that USDX don't have (based on date)
USDX.drop(columns=(['index']),axis=1,inplace=True)
USDX.info
# Out:
# <bound method DataFrame.info of             Date       Open       High        Low      Close  Adj Close  Volume
# 0     2010-01-04  77.930000  78.190002  77.260002  77.529999  77.529999     0.0
# 1     2010-01-05  77.370003  77.709999  77.089996  77.620003  77.620003     0.0
# 2     2010-01-06  77.650002  78.000000  77.360001  77.489998  77.489998     0.0
# 3     2010-01-07  77.370003  78.080002  77.300003  77.910004  77.910004     0.0
# 4     2010-01-08  77.980003  78.190002  77.349998  77.470001  77.470001     0.0
# ...          ...        ...        ...        ...        ...        ...     ...
# 2968  2021-11-17  95.940002  96.239998  95.730003  95.830002  95.830002     0.0
# 2969  2021-11-18  95.800003  95.839996  95.519997  95.540001  95.540001     0.0
# 2970  2021-11-19  95.589996  96.239998  95.580002  96.070000  96.070000     0.0
# 2971  2021-11-22  96.070000  96.550003  96.040001  96.500000  96.500000     0.0
# ...

# %%
#merge usdx and qqq dataframes
combined = pd.merge( USDX,QQQ, on="Date", how="inner")
combined.drop(columns=(['Open_x','High_x','Low_x','Volume_x','Adj Close_x','Open_y','High_y','Low_y','Adj Close_y','Volume_y']),axis=1,inplace = True)

combined.rename(columns={'Close_x':'USDX_price','Close_y':'QQQ_price'},inplace = True)
combined
# Out:
#             Date  USDX_price   QQQ_price
# 0     2010-01-04   77.529999   46.419998
# 1     2010-01-05   77.620003   46.419998
# 2     2010-01-06   77.489998   46.139999
# 3     2010-01-07   77.910004   46.169998
# 4     2010-01-08   77.470001   46.549999
# ...          ...         ...         ...
# 2967  2021-11-17   95.830002  397.630005
# 2968  2021-11-18   95.540001  401.750000
# 2969  2021-11-19   96.070000  403.989990
# 2970  2021-11-22   96.500000  399.299988
# 2971  2021-11-23   96.489998  397.480011
#
# [2972 rows x 3 columns]

# %%
#merge combined and xle dataframes
combined_1 = pd.merge( combined,XLE, on="Date", how="inner")
combined_1.drop(columns=['Open','High','Low','Adj Close','Volume'],inplace=True)
combined_1.rename(columns={'Close':'XLE_price'},inplace=True)
combined_1
# Out:
#             Date  USDX_price   QQQ_price  XLE_price
# 0     2010-01-04   77.529999   46.419998  58.810001
# 1     2010-01-05   77.620003   46.419998  59.290001
# 2     2010-01-06   77.489998   46.139999  60.000000
# 3     2010-01-07   77.910004   46.169998  59.910000
# 4     2010-01-08   77.470001   46.549999  60.299999
# ...          ...         ...         ...        ...
# 2967  2021-11-17   95.830002  397.630005  57.230000
# 2968  2021-11-18   95.540001  401.750000  56.889999
# 2969  2021-11-19   96.070000  403.989990  54.669998
# 2970  2021-11-22   96.500000  399.299988  55.639999
# 2971  2021-11-23   96.489998  397.480011  57.349998
#
# [2972 rows x 4 columns]

# %%
#merge combined and xlv dataframes
combined_2 = pd.merge( combined_1,XLV, on="Date", how="inner")
combined_2.drop(columns=['Open','High','Low','Adj Close','Volume'],inplace=True)
combined_2.rename(columns={'Close':'XLV_price'},inplace=True)
combined_2
# Out:
#             Date  USDX_price   QQQ_price  XLE_price   XLV_price
# 0     2010-01-04   77.529999   46.419998  58.810001   31.610001
# 1     2010-01-05   77.620003   46.419998  59.290001   31.299999
# 2     2010-01-06   77.489998   46.139999  60.000000   31.620001
# 3     2010-01-07   77.910004   46.169998  59.910000   31.730000
# 4     2010-01-08   77.470001   46.549999  60.299999   31.780001
# ...          ...         ...         ...        ...         ...
# 2967  2021-11-17   95.830002  397.630005  57.230000  133.729996
# 2968  2021-11-18   95.540001  401.750000  56.889999  133.779999
# 2969  2021-11-19   96.070000  403.989990  54.669998  132.970001
# 2970  2021-11-22   96.500000  399.299988  55.639999  132.369995
# 2971  2021-11-23   96.489998  397.480011  57.349998  132.509995
#
# [2972 rows x 5 columns]

# %%
combined_2['Date'] = pd.to_datetime(combined_2['Date'], infer_datetime_format = True)

# %%
l1 = plt.plot(combined_2['Date'],combined_2['USDX_price'], 'green', label='USDX')
l2 = plt.plot(combined_2['Date'],combined_2['QQQ_price'], 'red', label='QQQ')
l3 = plt.plot(combined_2['Date'],combined_2['XLE_price'], 'orange', label='XLE')
l4 = plt.plot(combined_2['Date'],combined_2['XLV_price'], 'blue', label='XLV')
plt.title('The Prices fluctuation from 2010 to 2021')
plt.legend()
plt.xticks(rotation = -45)
plt.xlabel("Date")
plt.ylabel("USDX and Three ETFs")
plt.show()

# %% [markdown]
# https://www.kaggle.com/freespirit08/time-series-for-beginners-with-arima
#
# reference

# %%
from datetime import datetime
import numpy as np             #for numerical computations like log,exp,sqrt etc
import pandas as pd            #for reading & storing data, pre-processing
import matplotlib.pylab as plt #for visualization
#for making sure matplotlib plots are generated in Jupyter notebook itself
# %matplotlib inline             
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10, 6

# %%
USDX['Date'] = pd.to_datetime(USDX['Date'],infer_datetime_format=True) #convert from string to datetime
indexedUSDX = USDX.set_index(['Date'])
indexedUSDX.drop(columns=(['Open','High','Low','Adj Close','Volume']),axis=1,inplace=True)
indexedUSDX
# Out:
#                 Close
# Date
# 2010-01-04  77.529999
# 2010-01-05  77.620003
# 2010-01-06  77.489998
# 2010-01-07  77.910004
# 2010-01-08  77.470001
# ...               ...
# 2021-11-17  95.830002
# 2021-11-18  95.540001
# 2021-11-19  96.070000
# 2021-11-22  96.500000
# 2021-11-23  96.489998
#
# [2973 rows x 1 columns]

# %%
#From the plot below, we can see that there is a Trend compoenent in th series. 
#Hence, we now check for stationarity of the data
## plot graph
plt.xlabel('Date')
plt.ylabel('Price')
plt.plot(indexedUSDX)

# %%
#Determine rolling statistics
rolmean = indexedUSDX.rolling(window=250).mean() #window size 250 denotes 250 days/year, giving rolling mean at yearly level
rolstd = indexedUSDX.rolling(window=250).std()
print(rolmean,rolstd)
# Out:
#                Close
# Date
# 2010-01-04       NaN
# 2010-01-05       NaN
# 2010-01-06       NaN
# 2010-01-07       NaN
# 2010-01-08       NaN
# ...              ...
# 2021-11-17  91.89292
# 2021-11-18  91.90580
# 2021-11-19  91.92092
# 2021-11-22  91.93736
# 2021-11-23  91.95328
#
# [2973 rows x 1 columns]                Close
# Date
# 2010-01-04       NaN
# 2010-01-05       NaN
# 2010-01-06       NaN
# 2010-01-07       NaN
# 2010-01-08       NaN
# ...              ...
# 2021-11-17  1.424471
# 2021-11-18  1.442788
# 2021-11-19  1.466443
# 2021-11-22  1.494493
# 2021-11-23  1.521571
#
# [2973 rows x 1 columns]

# %%
#Plot rolling statistics
orig = plt.plot(indexedUSDX, color='blue', label='Original Price')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='black', label='Rolling Std')
plt.legend(loc='best') #upper left location
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %% [markdown]
# "From the above graph, we see that rolling mean itself has a trend component even though rolling standard deviation is fairly constant with time. For our time series to be stationary, we need to ensure that both the rolling statistics ie: mean & std. dev. remain time invariant or constant with time. Thus the curves for both of them have to be parallel to the x-axis, which in our case is not so.
#
# To further augment our hypothesis that the time series is not stationary, let us perform the ADCF test."

# %%
#Perform Augmented Dickey–Fuller test:
print('Results of Dickey Fuller Test:')
dftest = adfuller(indexedUSDX['Close'], autolag='AIC')

dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
    
print(dfoutput)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                   -1.512097
# p-value                           0.527519
# #Lags Used                       11.000000
# Number of Observations Used    2961.000000
# Critical Value (1%)              -3.432560
# Critical Value (5%)              -2.862517
# Critical Value (10%)             -2.567290
# dtype: float64

# %% [markdown]
# We assume hypohesis that the time series is not-stationary.
# The mean is constant according to the plot, and the p-value is 0.52 not high enough to reject the hypothesis. Therefore, we think the time series is not-stationary.

# %%
#We still try to get it more stationary.
#Data Transformation to achieve Stationarity
#Estimating trend
indexedUSDX_logScale = np.log(indexedUSDX)
plt.plot(indexedUSDX_logScale)

# %%
#The below transformation is required to make series stationary
movingAverage = indexedUSDX_logScale.rolling(window=250).mean()
movingSTD = indexedUSDX_logScale.rolling(window=250).std()
plt.plot(indexedUSDX_logScale)
plt.plot(movingAverage, color='red')

# %%
#from the plot, the rolling mean is not stationary

datasetLogScaleMinusMovingAverage = indexedUSDX_logScale - movingAverage
datasetLogScaleMinusMovingAverage.head(20)

#Remove NAN values
datasetLogScaleMinusMovingAverage.dropna(inplace=True)
datasetLogScaleMinusMovingAverage.head(10)
# Out:
#                Close
# Date
# 2010-12-30 -0.020491
# 2010-12-31 -0.026749
# 2011-01-03 -0.025561
# 2011-01-04 -0.021750
# 2011-01-05 -0.011600
# 2011-01-06 -0.005186
# 2011-01-07 -0.002670
# 2011-01-10 -0.004475
# 2011-01-11 -0.005049
# 2011-01-12 -0.015411

# %%
def test_stationarity(timeseries):
    
    #Determine rolling statistics
    movingAverage = timeseries.rolling(window=250).mean()
    movingSTD = timeseries.rolling(window=250).std()
    
    #Plot rolling statistics
    orig = plt.plot(timeseries, color='blue', label='Original')
    mean = plt.plot(movingAverage, color='red', label='Rolling Mean')
    std = plt.plot(movingSTD, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey–Fuller test:
    print('Results of Dickey Fuller Test:')
    dftest = adfuller(timeseries['Close'], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(datasetLogScaleMinusMovingAverage)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                   -2.556918
# p-value                           0.102232
# #Lags Used                       13.000000
# Number of Observations Used    2710.000000
# Critical Value (1%)              -3.432765
# Critical Value (5%)              -2.862607
# Critical Value (10%)             -2.567338
# dtype: float64

# %%
#Now the p-value is extremely low. 
#And The critical values at 1%,5%,10% confidence intervals are not very close to the Test Statistic. 
#Thus, from above 2 points, we cannot say that our given series is stationary. 
#The rolling mean fluctuate up and down.

#But, in the spirit of getting higher accuracy, let us explore & try to find a better scale than our current log.

#Let us try out Exponential decay.

# %%
exponentialDecayWeightedAverage = indexedUSDX_logScale.ewm(halflife=250, min_periods=0, adjust=True).mean()
plt.plot(indexedUSDX_logScale)
plt.plot(exponentialDecayWeightedAverage, color='red')

# %%
#we perform the ADCF test again on the decay series below
datasetLogScaleMinusExponentialMovingAverage = indexedUSDX_logScale - exponentialDecayWeightedAverage
test_stationarity(datasetLogScaleMinusExponentialMovingAverage)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                   -2.519179
# p-value                           0.110877
# #Lags Used                       11.000000
# Number of Observations Used    2961.000000
# Critical Value (1%)              -3.432560
# Critical Value (5%)              -2.862517
# Critical Value (10%)             -2.567290
# dtype: float64

# %%
#p-value is very low.
#rolling std is stationary
#rolling average is fluctuating.

# %%
#Time Shift Transformation 
datasetLogDiffShifting = indexedUSDX_logScale - indexedUSDX_logScale.shift()
plt.plot(datasetLogDiffShifting)

# %%
datasetLogDiffShifting.dropna(inplace=True)
test_stationarity(datasetLogDiffShifting)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                -1.625276e+01
# p-value                        3.631480e-29
# #Lags Used                     1.000000e+01
# Number of Observations Used    2.961000e+03
# Critical Value (1%)           -3.432560e+00
# Critical Value (5%)           -2.862517e+00
# Critical Value (10%)          -2.567290e+00
# dtype: float64

# %%
#P-value is extremely low.
#rolling std and rolling mean are getting stationary.
#We have thus tried out 3 different transformation: log, exp decay & time shift. 
#For simplicity, we will go with the time shift scale.

# %%
#Let us now break down the 3 components of the time shift scale series using a system libary function. Once, 
#we separate our the components, we can simply ignore trend & seasonality and check on the nature of the residual part.

# %%
decomposition = seasonal_decompose(datasetLogDiffShifting,freq = 3) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(datasetLogDiffShifting, label='Original')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')

plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='best')

plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')

plt.tight_layout()

#there can be cases where an observation simply consisted of trend & seasonality. In that case, there won't be 
#any residual component & that would be a null or NaN. Hence, we also remove such cases.
decomposedLogData = residual
decomposedLogData.dropna(inplace=True)
test_stationarity(decomposedLogData)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                  -22.818912
# p-value                           0.000000
# #Lags Used                       29.000000
# Number of Observations Used    2940.000000
# Critical Value (1%)              -3.432576
# Critical Value (5%)              -2.862524
# Critical Value (10%)             -2.567294
# dtype: float64

# %%
#ACF & PACF plots

lag_acf = acf(datasetLogDiffShifting, nlags=20)
lag_pacf = pacf(datasetLogDiffShifting, nlags=20, method='ols')

#Plot ACF:
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y=0, linestyle='--', color='gray')
plt.axhline(y=-1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle='--', color='gray')
plt.title('Autocorrelation Function')            

#Plot PACF
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0, linestyle='--', color='gray')
plt.axhline(y=-1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle='--', color='gray')
plt.title('Partial Autocorrelation Function')
            
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:541: FutureWarning:
#
# fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.

# %% [markdown]
# From the ACF graph, we see that curve touches y=0.0 line at x=1. Thus, from theory, Q = 1 From the PACF graph, we see that curve touches y=0.0 line at x=1. Thus, from theory, P = 1
#
# ARIMA is AR + I + MA. Before, we see an ARIMA model, let us check the results of the individual AR & MA model. Note that, these models will give a value of RSS. Lower RSS values indicate a better model.

# %%
#Building Models
#AR Model
#making order=(1,1,0) gives RSS=
model = ARIMA(indexedUSDX_logScale, order=(1,1,1))
results_AR = model.fit(disp=-1)
plt.plot(datasetLogDiffShifting)
plt.plot(results_AR.fittedvalues, color='red')
plt.title('RSS: %.4f'%sum((results_AR.fittedvalues - datasetLogDiffShifting['Close'])**2))
print('Plotting AR model')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
# Plotting AR model

# %%
#MA Model
model = ARIMA(indexedUSDX_logScale, order=(0,1,1))
results_MA = model.fit(disp=-1)
plt.plot(datasetLogDiffShifting)
plt.plot(results_MA.fittedvalues, color='red')
plt.title('RSS: %.4f'%sum((results_MA.fittedvalues - datasetLogDiffShifting['Close'])**2))
print('Plotting MA model')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
# Plotting MA model

# %%
# AR+I+MA = ARIMA model
model = ARIMA(indexedUSDX_logScale, order=(1,1,1))
results_ARIMA = model.fit(disp=-1)
plt.plot(datasetLogDiffShifting)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS: %.4f'%sum((results_ARIMA.fittedvalues - datasetLogDiffShifting['Close'])**2))
print('Plotting ARIMA model')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
# Plotting ARIMA model

# %%
#Prediction & Reverse transformations 
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
print(predictions_ARIMA_diff.head())
# Out:
# Date
# 2010-01-05    0.000074
# 2010-01-06    0.000098
# 2010-01-07    0.000036
# 2010-01-08    0.000191
# 2010-01-11   -0.000045
# dtype: float64

# %%
#Convert to cumulative sum
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
print(predictions_ARIMA_diff_cumsum)
# Out:
# Date
# 2010-01-05    0.000074
# 2010-01-06    0.000172
# 2010-01-07    0.000208
# 2010-01-08    0.000400
# 2010-01-11    0.000355
#                 ...
# 2021-11-17    0.218349
# 2021-11-18    0.218413
# 2021-11-19    0.218415
# 2021-11-22    0.218606
# 2021-11-23    0.218792
# Length: 2972, dtype: float64

# %%
predictions_ARIMA_log = pd.Series(indexedUSDX_logScale['Close'].iloc[0], index=indexedUSDX_logScale.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum, fill_value=0)
predictions_ARIMA_log.head()
# Out:
# Date
# 2010-01-04    4.350665
# 2010-01-05    4.350739
# 2010-01-06    4.350837
# 2010-01-07    4.350873
# 2010-01-08    4.351065
# dtype: float64

# %%
# Inverse of log is exp.
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(indexedUSDX)
plt.plot(predictions_ARIMA)

# %%
indexedUSDX_logScale
# Out:
#                Close
# Date
# 2010-01-04  4.350665
# 2010-01-05  4.351825
# 2010-01-06  4.350149
# 2010-01-07  4.355554
# 2010-01-08  4.349891
# ...              ...
# 2021-11-17  4.562576
# 2021-11-18  4.559545
# 2021-11-19  4.565077
# 2021-11-22  4.569543
# 2021-11-23  4.569439
#
# [2973 rows x 1 columns]

# %%
#And we want to forecast for additional 2973 data points or 10 yrs.
results_ARIMA.plot_predict(5000)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:576: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:576: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:576: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-eedfd0f0db5a> in <module>()
#       1 #And we want to forecast for additional 2973 data points or 10 yrs.
# ----> 2 results_ARIMA.plot_predict(5000)
#
# ...

# %%
#The prediction plot is very bad. And the number of days we need to insert into the prediciton model
#is out of range. Therefore, we cannot use usdx as time series.
